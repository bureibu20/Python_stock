# %%
import requests
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import slackweb
import io

def data_analysis(url):  
    html = urlopen(url)
    bsObj = BeautifulSoup(html, "html.parser")
    table = bsObj.findAll("table")[0]
    rows = table.findAll("tr")[0:2]  #表の１行目を狙い撃ち

    for r in rows:
        tds = r.findAll("td")
        for td in tds[1:]:
            lnk = td.a.get("href")
            #print(lnk)
            if str(lnk).find('equities')>0 and str(lnk).find('xls')>0 and str(lnk).find('val')>0:
               #[si]0:東証プライム、1:東証スタンダード、2:グロース、3:二市場(名古屋と東証)]
               x=[Investor_data(lnk ,si) for si in range(0,4)] 

def Investor_data(pth,si):
    
    """投資部門別売買動向の差引データを取得する

    * slackに通知する場合には　"slack_url"を変更する！
    * 取得データを保存する場合には、#df3.to_csv("buysell_data{}.csv".format(si))をコメントアウト

    """

    url = 'https://www.jpx.co.jp/' + pth
    print(url , si)

    #データの読み込み(excel)
    df = pd.read_excel(url,  sheet_name=si)

    #期間日付、取引金額単位、市場名の取得
    mkt = df.iloc[4,0]
    mkt = str(mkt).replace('総売買代金', '')
    prd = df.iloc[2,0] 
    ymw = prd[:10]
    unit = df.iloc[3,10] 
    unit = unit.split(',')[0]
    unit = str(unit)
    reference = ymw + "/" + mkt + "/" + "単位"+ "(" + unit + ")"
    print(reference)
    
    df = df[11:63] 
    df.columns = ['a', 'b', 'c', 'd', 'e', 'f','g','h','i','j','k']
    df = df.drop(['c', 'd', 'e', 'f','g','h','j' ,'k'], axis=1)
    df = df[df['b']!='合計']
    df = df.dropna(subset=['i'])
    df = df.dropna(how='all')

    #値の置換
    dct = {'Proprietary': '自己計', 'Brokerage': '委託計', 'Total':'総　計', 'Institutions': '法　人'
          , 'Individuals': '個　人', 'Foreigners':'海外投資家','Securities Cos.':'証券会社'
          , 'Investment': '投資信託',  'Business Cos.':'事業法人', 'Other Cos.': 'その他法人等'
          , 'Financial': '金融機関', 'Life & Non-Life':'生保・損保', 'City & Regional BK':'都銀・地銀等'
          , 'Trust BK': '信託銀行',  'Other Financials':'その他金融機関'}
    df["a"] = df["a"].replace(dct)
    
    #整形：データの絞り込みや列名設定
    df = df.query("a not in ['委託計', '総　計', '法　人', '金融機関']")
    df.columns = ['投資主体', '売買', '金額'] 
    df = df.reset_index()
    
    #dfの集計: wide_formに変換
    df3 = df.pivot(index='投資主体', columns='売買', values='金額')
    df3 = df3.apply(lambda x: x.str.replace(',','')).astype(np.int)  #カンマ表記のString型をint型に変換
    df3['売買金額'] = df3['買い'] - df3['売り'] #売り買いの差引金額
    
    d_order = {'自己計': 0, '個　人': 1, '海外投資家': 2, '証券会社': 3
           , '投資信託': 4, '事業法人': 5, 'その他法人等': 6, '生保・損保': 7
           , '都銀・地銀等': 8, '信託銀行': 9, 'その他金融機関': 10}

    df3['order'] = df3.index.map(d_order)
    df3 = df3.sort_values('order')
    
    #再度カンマ表示に戻す
    df3 = df3.applymap('{:,}'.format) 
    
    #列名設定
    df3 = df3.drop(["売り", "買い", "order"], axis=1)
    display(df3)
    
    #データを保存する場合
    #df3.to_csv("buysell_data{}.csv".format(si))
    
    #slackに通知
    slack_url = "https://hooks.slack.com/services/xxxxxxxxxxxxxxxxxxxx"

    tsv = io.StringIO()
    df3.to_csv(tsv, sep='\t')

    slack = slackweb.Slack(url=slack_url)
    slack.notify(text=url + "\n" + reference + "\n" + tsv.getvalue())

# main
if __name__ == '__main__':
     url = 'https://www.jpx.co.jp/markets/statistics-equities/investor-type/00-00-archives-00.html'
     data_analysis(url)
# Out:
# https://www.jpx.co.jp//markets/statistics-equities/investor-type/nlsgeu000006eaie-att/stock_val_1_220501.xls 0
# 2022年5月第1週/東証プライム/単位(千円)
# 売買               売買金額
# 投資主体
# 自己計       -38,633,245
# 個　人      -135,421,946
# 海外投資家      59,176,365
# 証券会社       -5,102,095
# 投資信託       28,792,644
# 事業法人       18,761,568
# その他法人等      2,505,415
# 生保・損保     -12,411,039
# 都銀・地銀等     20,726,703
# 信託銀行       88,180,203
# その他金融機関    -7,201,906
# https://www.jpx.co.jp//markets/statistics-equities/investor-type/nlsgeu000006eaie-att/stock_val_1_220501.xls 1
# 2022年5月第1週/東証スタンダード/単位(千円)
# 売買             売買金額
# 投資主体
# 自己計         -69,697
# 個　人      -1,438,442
# 海外投資家      -549,682
# 証券会社        228,161
# 投資信託        850,233
# 事業法人         62,138
# その他法人等      360,753
# 生保・損保       -45,138
# 都銀・地銀等      205,292
# 信託銀行        431,996
# その他金融機関         683
# https://www.jpx.co.jp//markets/statistics-equities/investor-type/nlsgeu000006eaie-att/stock_val_1_220501.xls 2
# 2022年5月第1週/東証グロース/単位(千円)
# 売買             売買金額
# 投資主体
# 自己計         -70,395
# 個　人       7,379,990
# 海外投資家    -7,203,045
# 証券会社        303,311
# 投資信託       -247,456
# 事業法人       -211,985
# その他法人等       46,123
# 生保・損保       -12,906
# 都銀・地銀等      -44,219
# 信託銀行        -82,805
# その他金融機関      -5,174
# https://www.jpx.co.jp//markets/statistics-equities/investor-type/nlsgeu000006eaie-att/stock_val_1_220501.xls 3
# 2022年5月第1週/二市場/単位(千円)
# 売買               売買金額
# 投資主体
# 自己計       -38,774,053
# 個　人      -129,511,393
# 海外投資家      51,457,523
# 証券会社       -4,582,077
# 投資信託       29,395,175
# 事業法人       18,615,967
# その他法人等      2,926,111
# 生保・損保     -12,469,708
# 都銀・地銀等     20,887,538
# 信託銀行       88,527,898
# その他金融機関    -7,206,397
